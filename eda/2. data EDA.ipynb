# %% [markdown]
# # #1 데이터 기본 구조 확인

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
train_cn7 = pd.read_csv(r"C:\dev\KAMP_hoochuteam\data\train\moldset_labeled_cn7.csv")
train_rg3 = pd.read_csv(r"C:\dev\KAMP_hoochuteam\data\train\moldset_labeled_rg3.csv")

# %% [markdown]
# ### 1) 데이터 크기 shape

# %%
train_cn7.shape, train_rg3.shape
# Out:
# ((1211, 26), (1182, 26))

# %% [markdown]
# ### 2) 컬럼명 확인

# %%
train_cn7.columns, train_rg3.columns
# Out:
# (Index(['Unnamed: 0', 'PassOrFail', 'Injection_Time', 'Filling_Time',
#         'Plasticizing_Time', 'Cycle_Time', 'Clamp_Close_Time',
#         'Cushion_Position', 'Plasticizing_Position', 'Clamp_Open_Position',
#         'Max_Injection_Speed', 'Max_Screw_RPM', 'Average_Screw_RPM',
#         'Max_Injection_Pressure', 'Max_Switch_Over_Pressure',
#         'Max_Back_Pressure', 'Average_Back_Pressure', 'Barrel_Temperature_1',
#         'Barrel_Temperature_2', 'Barrel_Temperature_3', 'Barrel_Temperature_4',
#         'Barrel_Temperature_5', 'Barrel_Temperature_6', 'Hopper_Temperature',
#         'Mold_Temperature_3', 'Mold_Temperature_4'],
#        dtype='str'),
#  Index(['Unnamed: 0', 'PassOrFail', 'Injection_Time', 'Filling_Time',
#         'Plasticizing_Time', 'Cycle_Time', 'Clamp_Close_Time',
#         'Cushion_Position', 'Plasticizing_Position', 'Clamp_Open_Position',
#         'Max_Injection_Speed', 'Max_Screw_RPM', 'Average_Screw_RPM',
#         'Max_Injection_Pressure', 'Max_Switch_Over_Pressure',
#         'Max_Back_Pressure', 'Average_Back_Pressure', 'Barrel_Temperature_1',
#         'Barrel_Temperature_2', 'Barrel_Temperature_3', 'Barrel_Temperature_4',
#         'Barrel_Temperature_5', 'Barrel_Temperature_6', 'Hopper_Temperature',
#         'Mold_Temperature_3', 'Mold_Temperature_4'],
#        dtype='str'))

# %% [markdown]
# ### 3) 데이터 타입 확인

# %%
train_cn7.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1211 non-null   int64
#  1   PassOrFail                1211 non-null   int64
#  2   Injection_Time            1211 non-null   float64
#  3   Filling_Time              1211 non-null   float64
#  4   Plasticizing_Time         1211 non-null   float64
#  5   Cycle_Time                1211 non-null   float64
#  6   Clamp_Close_Time          1211 non-null   float64
#  7   Cushion_Position          1211 non-null   float64
#  8   Plasticizing_Position     1211 non-null   float64
#  9   Clamp_Open_Position       1211 non-null   float64
#  10  Max_Injection_Speed       1211 non-null   float64
#  11  Max_Screw_RPM             1211 non-null   float64
#  12  Average_Screw_RPM         1211 non-null   float64
#  13  Max_Injection_Pressure    1211 non-null   float64
#  14  Max_Switch_Over_Pressure  1211 non-null   float64
#  15  Max_Back_Pressure         1211 non-null   float64
#  16  Average_Back_Pressure     1211 non-null   float64
#  17  Barrel_Temperature_1      1211 non-null   float64
#  18  Barrel_Temperature_2      1211 non-null   float64
#  19  Barrel_Temperature_3      1211 non-null   float64
#  20  Barrel_Temperature_4      1211 non-null   float64
#  21  Barrel_Temperature_5      1211 non-null   float64
#  22  Barrel_Temperature_6      1211 non-null   float64
#  23  Hopper_Temperature        1211 non-null   float64
#  24  Mold_Temperature_3        1211 non-null   float64
#  25  Mold_Temperature_4        1211 non-null   float64
# dtypes: float64(24), int64(2)
# memory usage: 246.1 KB

# %%
train_rg3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1182 non-null   int64
#  1   PassOrFail                1182 non-null   int64
#  2   Injection_Time            1182 non-null   float64
#  3   Filling_Time              1182 non-null   float64
#  4   Plasticizing_Time         1182 non-null   float64
#  5   Cycle_Time                1182 non-null   float64
#  6   Clamp_Close_Time          1182 non-null   float64
#  7   Cushion_Position          1182 non-null   float64
#  8   Plasticizing_Position     1182 non-null   float64
#  9   Clamp_Open_Position       1182 non-null   float64
#  10  Max_Injection_Speed       1182 non-null   float64
#  11  Max_Screw_RPM             1182 non-null   float64
#  12  Average_Screw_RPM         1182 non-null   float64
#  13  Max_Injection_Pressure    1182 non-null   float64
#  14  Max_Switch_Over_Pressure  1182 non-null   float64
#  15  Max_Back_Pressure         1182 non-null   float64
#  16  Average_Back_Pressure     1182 non-null   float64
#  17  Barrel_Temperature_1      1182 non-null   float64
#  18  Barrel_Temperature_2      1182 non-null   float64
#  19  Barrel_Temperature_3      1182 non-null   float64
#  20  Barrel_Temperature_4      1182 non-null   float64
#  21  Barrel_Temperature_5      1182 non-null   float64
#  22  Barrel_Temperature_6      1182 non-null   float64
#  23  Hopper_Temperature        1182 non-null   float64
#  24  Mold_Temperature_3        1182 non-null   float64
#  25  Mold_Temperature_4        1182 non-null   float64
# dtypes: float64(24), int64(2)
# memory usage: 240.2 KB

# %% [markdown]
# ### 4) 수치형 / 범주형 / 날짜형 변수 구분

# %%
train_cn7_num = train_cn7.select_dtypes(include=np.number)
train_cn7_str = train_cn7.select_dtypes(exclude=np.number)

train_rg3_num = train_rg3.select_dtypes(include=np.number)
train_rg3_str = train_rg3.select_dtypes(exclude=np.number)

# %% [markdown]
# ### 5) 각 컬럼 의미 정리

# %% [markdown]
# ### 6) Target / ID / 설명변수 구분

# %%
train_cn7['PassOrFail'].

# %% [markdown]
# # #2 데이터 품질 확인

# %% [markdown]
# ### 1) 결측치 개수 / 비율

# %% [markdown]
# ### 2) 완전 중복 행 확인

# %% [markdown]
# ### 3) ID성 컬럼 중복 확인

# %% [markdown]
# ### 4) 컬럼별 고유값 개수 확인

# %% [markdown]
# ### 5) 상수 컬럼 확인

# %% [markdown]
# ### 6) 거의 한 값만 존재하는 컬럼 확인

# %% [markdown]
# ### 7) 잘못된 데이터 타입 확인

# %% [markdown]
# ### 8) 논리적으로 불가능한 값 확인

# %% [markdown]
# ### 9) 범위를 벗어난 값 확인

# %% [markdown]
# ### 10) 날짜 범위 이상 여부 확인

# %% [markdown]
# # #3 Target 확인

# %% [markdown]
# ### 1) Target 종류 확인

# %% [markdown]
# ### 2) 분류 / 회귀 문제 구분

# %% [markdown]
# ### 3) 분류 문제일 경우 Target 클래스 개수

# %% [markdown]
# ### 4) 클래스별 데이터 수

# %% [markdown]
# ### 5) 클래스별 비율

# %% [markdown]
# ### 6) 클래스 불균형 여부 확인

# %% [markdown]
# ### 7) 회귀 문제일 경우 Target 평균 / 중앙값

# %% [markdown]
# ### 8) 최소 / 최대값

# %% [markdown]
# ### 9) 표준편차

# %% [markdown]
# ### 10) Target 분포 확인

# %% [markdown]
# ### 11) 왜도 확인

# %% [markdown]
# ### 12) 극단값 확인

# %% [markdown]
# # #4 수치형 변수 기초 통계

# %% [markdown]
# ### 1) 평균

# %% [markdown]
# ### 2) 중앙값

# %% [markdown]
# ### 3) 표준편차

# %% [markdown]
# ### 4) 최소값 / 최대값

# %% [markdown]
# ### 5) 사분위수

# %% [markdown]
# ### 6) 왜도

# %% [markdown]
# ### 7) 첨도

# %% [markdown]
# ### 8) 0 또는 특정 값에 데이터가 몰려있는지 확인

# %% [markdown]
# # #5 수치형 변수 분포 분석

# %% [markdown]
# ### 1) Histogram

# %% [markdown]
# ### 2) KDE Plot

# %% [markdown]
# ### 3) Boxplot

# %% [markdown]
# ### 4) 분포의 치우침 확인

# %% [markdown]
# ### 5) 극단값 확인

# %% [markdown]
# ### 6) 이상치 후보 탐색

# %% [markdown]
# ### 7) 로그 변환이 필요한 변수 확인

# %% [markdown]
# ### 8) 변수별 스케일 차이 확인

# %% [markdown]
# # #6 범주형 변수 분석

# %% [markdown]
# ### 1) 카테고리 종류 수

# %% [markdown]
# ### 2) 카테고리별 빈도수

# %% [markdown]
# ### 3) 카테고리별 비율

# %% [markdown]
# ### 4) 고유값이 지나치게 많은 변수 확인

# %% [markdown]
# ### 5) 희소한 범주 확인

# %% [markdown]
# ### 6) 거의 한 범주만 존재하는 변수 확인

# %% [markdown]
# ### 7) 오타 / 표기 방식 차이 확인

# %% [markdown]
# ### 8) 통합 가능한 범주 확인

# %% [markdown]
# # #7 날짜 / 시간 변수 분석

# %% [markdown]
# ### 1) 데이터 수집 기간 확인

# %% [markdown]
# ### 2) 최초 날짜 / 최근 날짜 확인

# %% [markdown]
# ### 3) 연도별 분포

# %% [markdown]
# ### 4) 월별 분포

# %% [markdown]
# ### 5) 요일별 분포

# %% [markdown]
# ### 6) 시간대별 분포

# %% [markdown]
# ### 7) 기간별 데이터 수 변화 확인

# %% [markdown]
# ### 8) 특정 시점에 데이터가 집중되는지 확인

# %% [markdown]
# ### 9) 데이터가 없는 기간 확인

# %% [markdown]
# # #8 Target별 수치형 변수 비교

# %% [markdown]
# ### 1) 클래스별 평균 비교

# %% [markdown]
# ### 2) 클래스별 중앙값 비교

# %% [markdown]
# ### 3) 클래스별 표준편차 비교

# %% [markdown]
# ### 4) Boxplot 비교

# %% [markdown]
# ### 5) Histogram / KDE 비교

# %% [markdown]
# ### 6) 두 그룹 간 분포 차이 확인

# %% [markdown]
# ### 7) Target별 차이가 큰 변수 탐색

# %% [markdown]
# # #9 Target별 범주형 변수 비교

# %% [markdown]
# ### 1) 범주별 Target 개수 비교

# %% [markdown]
# ### 2) 범주별 Target 비율 비교

# %% [markdown]
# ### 3) Target별 범주 분포 비교

# %% [markdown]
# ### 4) 특정 범주에서 Target 발생률이 높은지 확인

# %% [markdown]
# ### 5) 희소 범주에서 특이 패턴이 발생하는지 확인

# %% [markdown]
# # #10 변수 간 상관관계 분석

# %% [markdown]
# ### 1) 수치형 변수 상관계수 확인

# %% [markdown]
# ### 2) Correlation Heatmap

# %% [markdown]
# ### 3) 강한 양의 상관관계 확인

# %% [markdown]
# ### 4) 강한 음의 상관관계 확인

# %% [markdown]
# ### 5) 서로 거의 동일하게 움직이는 변수 확인

# %% [markdown]
# ### 6) 중복 정보를 가지는 변수 확인

# %% [markdown]
# ### 7) 다중공선성 후보 확인

# %% [markdown]
# ### 8) Target과 상관관계가 높은 변수 확인

# %% [markdown]
# # #11 변수 간 관계 분석

# %% [markdown]
# ### 1) 수치형 × 수치형 관계 확인

# %% [markdown]
# ### 2) Scatter Plot

# %% [markdown]
# ### 3) 범주형 × 수치형 관계 확인

# %% [markdown]
# ### 4) 범주별 평균 / 중앙값 비교

# %% [markdown]
# ### 5) 범주형 × 범주형 관계 확인

# %% [markdown]
# ### 6) 교차표 crosstab 확인

# %% [markdown]
# ### 7) 두 변수 조합에서 Target 차이가 발생하는지 확인

# %% [markdown]
# # #12 이상치 분석

# %% [markdown]
# ### 1) IQR 기준 이상치 확인

# %% [markdown]
# ### 2) Z-score 기준 이상치 확인

# %% [markdown]
# ### 3) Boxplot 확인

# %% [markdown]
# ### 4) 상위 / 하위 극단값 직접 확인

# %% [markdown]
# ### 5) 특정 변수에서 이상치가 집중되는지 확인

# %% [markdown]
# ### 6) 특정 그룹에서만 이상치가 발생하는지 확인

# %% [markdown]
# ### 7) Target과 이상치의 관계 확인

# %% [markdown]
# ### 8) 실제 이상 데이터인지 정상적인 극단값인지 확인

# %% [markdown]
# # #13 ID / 그룹 구조 확인

# %% [markdown]
# ### 1) ID별 데이터 개수

# %% [markdown]
# ### 2) 그룹별 데이터 개수

# %% [markdown]
# ### 3) 카테고리별 데이터 개수

# %% [markdown]
# ### 4) 그룹별 Target 비율

# %% [markdown]
# ### 5) 특정 그룹에 데이터가 편중되어 있는지 확인

# %% [markdown]
# ### 6) 한 ID가 여러 행을 가지는 구조인지 확인

# %% [markdown]
# ### 7) 동일 ID 데이터가 Train / Test에 섞일 가능성 확인

# %% [markdown]
# # #14 데이터 불균형 / 편향 확인

# %% [markdown]
# ### 1) Target 불균형 확인

# %% [markdown]
# ### 2) 특정 그룹 편중 확인

# %% [markdown]
# ### 3) 특정 기간에 데이터 집중 여부 확인

# %% [markdown]
# ### 4) 특정 카테고리 데이터 과다 여부 확인

# %% [markdown]
# ### 5) 소수 그룹의 표본 수 확인

# %% [markdown]
# ### 6) Train / Test 분포 차이 가능성 확인

# %% [markdown]
# # #15 파생변수 후보 탐색

# %% [markdown]
# ### 1) 변수 간 비율

# %% [markdown]
# ### 2) 변수 간 차이

# %% [markdown]
# ### 3) 합계

# %% [markdown]
# ### 4) 평균

# %% [markdown]
# ### 5) 최댓값 / 최솟값

# %% [markdown]
# ### 6) 누적값

# %% [markdown]
# ### 7) 횟수

# %% [markdown]
# ### 8) 빈도

# %% [markdown]
# ### 9) 최근 N개 평균

# %% [markdown]
# ### 10) 최근 N개 합계

# %% [markdown]
# ### 11) 변화량

# %% [markdown]
# ### 12) 변화율

# %% [markdown]
# ### 13) 시간 간격

# %% [markdown]
# ### 14) 최근 활동 이후 경과 시간

# %% [markdown]
# ### 15) 그룹 내 평균 / 순위 / 편차

# %% [markdown]
# ### 16) 여러 범주 조합

# %% [markdown]
# ### 17) 날짜 기반 연 / 월 / 요일 / 시간대 파생

# %% [markdown]
# # #16 데이터 누수 가능성 확인

# %% [markdown]
# ### 1) Target 결정 이후 생성되는 변수 확인

# %% [markdown]
# ### 2) Target 정보를 직접 포함하는 변수 확인

# %% [markdown]
# ### 3) 결과값과 사실상 동일한 컬럼 확인

# %% [markdown]
# ### 4) 미래 시점의 정보가 포함되어 있는지 확인

# %% [markdown]
# ### 5) Train 단계에서는 알 수 없는 정보인지 확인

# %% [markdown]
# ### 6) ID를 통해 Target을 간접적으로 알 수 있는지 확인

# %% [markdown]
# # #17 모델링 전 변수 점검

# %% [markdown]
# ### 1) 사용하지 않을 ID성 컬럼 확인

# %% [markdown]
# ### 2) 상수 컬럼 제거 후보 확인

# %% [markdown]
# ### 3) 결측치 처리 필요 변수 확인

# %% [markdown]
# ### 4) 범주형 인코딩 필요 변수 확인

# %% [markdown]
# ### 5) 스케일링 필요 변수 확인

# %% [markdown]
# ### 6) 로그 변환 후보 확인

# %% [markdown]
# ### 7) 다중공선성 변수 확인

# %% [markdown]
# ### 8) 파생변수 후보 정리

# %% [markdown]
# ### 9) Feature / Target 최종 구분

# %% [markdown]
# # #18 EDA 최종 인사이트 정리

# %% [markdown]
# ### 1) Target 분포 특징

# %% [markdown]
# ### 2) 데이터 품질 문제

# %% [markdown]
# ### 3) 주요 결측 변수

# %% [markdown]
# ### 4) 주요 이상치 변수

# %% [markdown]
# ### 5) Target별 차이가 큰 변수

# %% [markdown]
# ### 6) Target과 관계가 강한 변수

# %% [markdown]
# ### 7) 변수 간 강한 관계

# %% [markdown]
# ### 8) 특이한 그룹 패턴

# %% [markdown]
# ### 9) 시간에 따른 변화 패턴

# %% [markdown]
# ### 10) 파생변수 후보

# %% [markdown]
# ### 11) 제거 또는 전처리가 필요한 변수

# %% [markdown]
# ### 12) 모델링
